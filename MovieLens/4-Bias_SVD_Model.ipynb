# %%
# 模块和包都是在逐步的探索中所需要的，全部汇总到这里，
#    并不是一开始就知道了 ^_^ ^_^ ^_^ 
# 不熟悉的模块和包，强烈建议查看官方文档说明以及例子
# 1、导入模块和包
import pandas as pd    # 加载并处理csv文件
import datetime        # 利用datetime处理时间戳
# cPickle 数据以二进制进行高效的储存到文件
import _pickle as cPickle 
# defaultdict 设置稀疏矩阵的 NULL 位置的默认值
from collections import defaultdict 
# 利用scipy sparse 构建稀疏矩阵
import scipy.sparse as ss     
import scipy.io as sio    # 利用scipy储存评分矩阵
# 利用numpy创建指定长度或形状的矩阵以及矩阵运算
import numpy as np 
# numpy.random中的randn函数生成正态分布的随机数据
from numpy.random import random    
import time    # 计算训练时迭代的时间
import json    # 将模型参数保存和加载 json文件
import scipy    # 将储存加载的稀疏评分矩阵转换为numpy矩阵

# %%
# 加载训练集数据
data_path = "./../dataset/ml-25m/"
train = pd.read_csv(data_path + "train.csv", sep = ",", nrows = 2000)
# 计算用户数量和电影数量
unique_user = train['userId'].unique()
unique_item = train['movieId'].unique()
user_num = unique_user.shape[0]
item_num = unique_item.shape[0]
print("the number of user:",user_num)
print("the number of movie:",item_num)
# Out:
# the number of user: 1956
# the number of movie: 1340

# %%
# 4、模型探索
# 4.1、BiasSVD r(ui) = average + bu + bi + Pu'T Qi
# 4.1.1、初始化BiasSVD模型参数
# 隐含变量的维数 m*n = m*k * k*n
# 设置参数变量，可以随时调整模型参数值
# 18 个电影类型 10、12、14、16、18、20、24、36
k = 12
# Item和User的偏置项
# zeros和ones分别可以创建指定长度或形状的全0或全1数组。
bi = np.zeros((item_num, 1))    # n 行 1 列
bu = np.zeros((user_num, 1))    # m 行 1 列
# Item和User的隐含向量
qi = np.zeros((item_num, k))    # n 行 k 列    
pu = np.zeros((user_num, k))    # m 行 k 列
# 使用numpy.random中的randn函数生成一些正态分布的随机数据
# pu和qi，两个矩阵的初始化，可以使全为零
# 也可以符合正态分布（高斯分布），同时也隐向量维度k的平方有关
for user_id in range(user_num):
    pu[user_id] = np.reshape(random((k, 1)) / 10 * np.sqrt(k), k)
       
for item_id in range(item_num):
    qi[item_id] = np.reshape(random((k, 1)) / 10 * np.sqrt(k), k)

# 所有用户的平均打分
average = train['rating'].mean()

# %%
# 4.1.2、根据初始化BiasSVD模型参数进行预测评分
# 根据当前模型参数，预测用户对物品打分
def BiasSVD_prediction(user_id, item_id):  
    score = average + bi[item_id] + bu[user_id] + np.sum(qi[item_id] * pu[user_id]) 
    return score

# %%
# 加载重新索引的用户索引表
user_index = cPickle.load(open(data_path + "user_index.pkl", 'rb'))
# 加载重新索引的电影索引表
item_index = cPickle.load(open(data_path + "item_index.pkl", 'rb'))

# %%
# 4.1.3、BiasSVD模型训练
# 参数：gamma —学习率、Lambda —正则参数、steps —迭代次数
# 初始化BiasSVD模型超参数
# 迭代次数：20、40、60、80、100
steps = 100
#each_rmse_list = list()
gamma = 0.005
#each_gamma_list = list()
Lambda = 0.15
# 总的评分记录数目
total_records = train.shape[0]
# 第一次迭代时间开始
time_start = time.time()
print("开始进行{}个step的训练".format(steps))
each_time_start = time_start

for step in range(steps):
    print('The {}-th  step is running'.format(step))
    rmse_sum = 0.0    # 真实评分与预测评分的差值的平方            
    # 利用numpy.random.permutation函数可以轻松实现
    #   对Series或DataFrame的列的排列工作，随机重排序
    # 通过需要排列的轴的长度调用permutation， 
    #   可产生一个表示新顺序的整数数组
    # 将训练样本打散顺序 
    total_num = np.random.permutation(total_records)  
    for index in range(total_records):
        # 每次一个训练样本,即一条记录
        row = total_num[index]
        
        user_id = user_index[ train.iloc [row] ['userId'] ]
        item_id = item_index[ train.iloc [row] ['movieId'] ]
        rating = train.iloc[row]['rating']
        
        # 目标函数构建
        # 预测残差
        eui = rating - BiasSVD_prediction(user_id, item_id)
        # residual sum of squares 残差平方和 
        rmse_sum += eui**2

        # 随机梯度下降，更新
        bu[user_id] += gamma * (eui - Lambda * bu[user_id])  
        bi[item_id] += gamma * (eui - Lambda * bi[item_id])
                
        temp = qi[item_id]  
        qi[item_id] += gamma * (eui * pu[user_id] - Lambda * qi[item_id])
        pu[user_id] += gamma * (eui * temp - Lambda * pu[user_id])
            
    # 学习率递减 / learning rate improve 3th
    #each_gamma_list.append(gamma)
    gamma = gamma * 0.93
    # Root Mean Square Error RMSE
    each_rmse = np.sqrt(rmse_sum / total_records)
    #each_rmse_list.append(each_rmse)
    
    # 每次迭代时间结束
    each_time_tick = time.time()
    # 每次迭代消耗的时间
    each_cost_time = each_time_tick - each_time_start
    # 更新计算每次迭代的时间
    each_time_start = each_time_tick
    print("完成第{}个step的训练, each_rmse={}, 耗时{:.4f}秒".format(
        step + 1, each_rmse, each_cost_time))

# 计算训练数据集消耗的总时间
time_end = time.time()
total_cost_time = time_end - time_start
print("结束了{}个step的训练，总耗时{:.4f}秒".format(steps, total_cost_time))
# Out:
# 开始进行100个step的训练
# The 0-th  step is running
# 完成第1个step的训练, each_rmse=[0.95713933], 耗时3.1462秒
# The 1-th  step is running
# 完成第2个step的训练, each_rmse=[0.94364729], 耗时3.0772秒
# The 2-th  step is running
# 完成第3个step的训练, each_rmse=[0.93139928], 耗时3.0202秒
# The 3-th  step is running
# 完成第4个step的训练, each_rmse=[0.92024546], 耗时3.0782秒
# The 4-th  step is running
# 完成第5个step的训练, each_rmse=[0.91007157], 耗时3.0272秒
# The 5-th  step is running
# 完成第6个step的训练, each_rmse=[0.9007828], 耗时3.1762秒
# The 6-th  step is running
# 完成第7个step的训练, each_rmse=[0.8922845], 耗时3.1222秒
# The 7-th  step is running
# 完成第8个step的训练, each_rmse=[0.88450418], 耗时3.0412秒
# The 8-th  step is running
# 完成第9个step的训练, each_rmse=[0.87736062], 耗时3.0392秒
# The 9-th  step is running
# 完成第10个step的训练, each_rmse=[0.87081282], 耗时3.0362秒
# The 10-th  step is running
# 完成第11个step的训练, each_rmse=[0.86478327], 耗时3.0252秒
# The 11-th  step is running
# 完成第12个step的训练, each_rmse=[0.8592449], 耗时3.0852秒
# The 12-th  step is running
# 完成第13个step的训练, each_rmse=[0.85414705], 耗时3.0192秒
# The 13-th  step is running
# 完成第14个step的训练, each_rmse=[0.84944482], 耗时3.0772秒
# The 14-th  step is running
# 完成第15个step的训练, each_rmse=[0.84511323], 耗时3.0112秒
# The 15-th  step is running
# 完成第16个step的训练, each_rmse=[0.84111335], 耗时3.0552秒
# The 16-th  step is running
# 完成第17个step的训练, each_rmse=[0.83742415], 耗时3.0272秒
# The 17-th  step is running
# 完成第18个step的训练, each_rmse=[0.83401618], 耗时3.1132秒
# The 18-th  step is running
# 完成第19个step的训练, each_rmse=[0.83086516], 耗时3.0392秒
# The 19-th  step is running
# 完成第20个step的训练, each_rmse=[0.82795489], 耗时3.0312秒
# The 20-th  step is running
# 完成第21个step的训练, each_rmse=[0.82526021], 耗时3.0612秒
# The 21-th  step is running
# 完成第22个step的训练, each_rmse=[0.82276765], 耗时3.0652秒
# The 22-th  step is running
# 完成第23个step的训练, each_rmse=[0.82046232], 耗时3.0312秒
# The 23-th  step is running
# 完成第24个step的训练, each_rmse=[0.81832513], 耗时3.0292秒
# The 24-th  step is running
# 完成第25个step的训练, each_rmse=[0.81634621], 耗时3.0802秒
# The 25-th  step is running
# 完成第26个step的训练, each_rmse=[0.8145139], 耗时2.9892秒
# The 26-th  step is running
# 完成第27个step的训练, each_rmse=[0.81281492], 耗时3.0702秒
# The 27-th  step is running
# 完成第28个step的训练, each_rmse=[0.81123804], 耗时3.0072秒
# The 28-th  step is running
# 完成第29个step的训练, each_rmse=[0.80977821], 耗时3.0722秒
# The 29-th  step is running
# 完成第30个step的训练, each_rmse=[0.80842319], 耗时3.0132秒
# The 30-th  step is running
# 完成第31个step的训练, each_rmse=[0.80716744], 耗时3.0652秒
# The 31-th  step is running
# 完成第32个step的训练, each_rmse=[0.80600118], 耗时3.0832秒
# The 32-th  step is running
# 完成第33个step的训练, each_rmse=[0.80491952], 耗时3.0522秒
# The 33-th  step is running
# 完成第34个step的训练, each_rmse=[0.80391551], 耗时3.0442秒
# The 34-th  step is running
# 完成第35个step的训练, each_rmse=[0.80298406], 耗时3.0992秒
# The 35-th  step is running
# 完成第36个step的训练, each_rmse=[0.80211826], 耗时3.0082秒
# The 36-th  step is running
# 完成第37个step的训练, each_rmse=[0.80131574], 耗时3.0662秒
# The 37-th  step is running
# 完成第38个step的训练, each_rmse=[0.80056975], 耗时3.0202秒
# The 38-th  step is running
# 完成第39个step的训练, each_rmse=[0.79987677], 耗时3.0622秒
# The 39-th  step is running
# 完成第40个step的训练, each_rmse=[0.79923383], 耗时3.0472秒
# The 40-th  step is running
# 完成第41个step的训练, each_rmse=[0.79863569], 耗时3.0352秒
# The 41-th  step is running
# 完成第42个step的训练, each_rmse=[0.79808083], 耗时3.0402秒
# The 42-th  step is running
# 完成第43个step的训练, each_rmse=[0.79756529], 耗时4.2242秒
# The 43-th  step is running
# 完成第44个step的训练, each_rmse=[0.79708592], 耗时3.2592秒
# The 44-th  step is running
# 完成第45个step的训练, each_rmse=[0.79664109], 耗时3.1662秒
# The 45-th  step is running
# 完成第46个step的训练, each_rmse=[0.79622728], 耗时3.1422秒
# The 46-th  step is running
# 完成第47个step的训练, each_rmse=[0.79584294], 耗时3.1442秒
# The 47-th  step is running
# 完成第48个step的训练, each_rmse=[0.79548595], 耗时3.1002秒
# The 48-th  step is running
# 完成第49个step的训练, each_rmse=[0.7951537], 耗时3.1662秒
# The 49-th  step is running
# 完成第50个step的训练, each_rmse=[0.79484526], 耗时3.1072秒
# The 50-th  step is running
# 完成第51个step的训练, each_rmse=[0.79455817], 耗时3.2462秒
# The 51-th  step is running
# 完成第52个step的训练, each_rmse=[0.79429209], 耗时3.1032秒
# The 52-th  step is running
# 完成第53个step的训练, each_rmse=[0.79404406], 耗时3.1222秒
# The 53-th  step is running
# 完成第54个step的训练, each_rmse=[0.79381364], 耗时3.1412秒
# The 54-th  step is running
# 完成第55个step的训练, each_rmse=[0.79359957], 耗时3.1052秒
# The 55-th  step is running
# 完成第56个step的训练, each_rmse=[0.7934005], 耗时3.1302秒
# The 56-th  step is running
# 完成第57个step的训练, each_rmse=[0.79321546], 耗时3.1202秒
# The 57-th  step is running
# 完成第58个step的训练, each_rmse=[0.79304346], 耗时3.1152秒
# The 58-th  step is running
# 完成第59个step的训练, each_rmse=[0.79288358], 耗时3.1082秒
# The 59-th  step is running
# 完成第60个step的训练, each_rmse=[0.79273482], 耗时3.1252秒
# The 60-th  step is running
# 完成第61个step的训练, each_rmse=[0.79259663], 耗时3.1642秒
# The 61-th  step is running
# 完成第62个step的训练, each_rmse=[0.79246811], 耗时3.2212秒
# The 62-th  step is running
# 完成第63个step的训练, each_rmse=[0.79234866], 耗时3.0952秒
# The 63-th  step is running
# 完成第64个step的训练, each_rmse=[0.79223752], 耗时3.1362秒
# The 64-th  step is running
# 完成第65个step的训练, each_rmse=[0.79213415], 耗时3.0832秒
# The 65-th  step is running
# 完成第66个step的训练, each_rmse=[0.79203809], 耗时3.1692秒
# The 66-th  step is running
# 完成第67个step的训练, each_rmse=[0.79194883], 耗时3.0972秒
# The 67-th  step is running
# 完成第68个step的训练, each_rmse=[0.79186573], 耗时3.1512秒
# The 68-th  step is running
# 完成第69个step的训练, each_rmse=[0.79178853], 耗时3.1012秒
# The 69-th  step is running
# 完成第70个step的训练, each_rmse=[0.7917167], 耗时3.1802秒
# The 70-th  step is running
# 完成第71个step的训练, each_rmse=[0.79164992], 耗时3.0832秒
# The 71-th  step is running
# 完成第72个step的训练, each_rmse=[0.79158787], 耗时3.2222秒
# The 72-th  step is running
# 完成第73个step的训练, each_rmse=[0.79153015], 耗时3.1212秒
# The 73-th  step is running
# 完成第74个step的训练, each_rmse=[0.79147642], 耗时3.1322秒
# The 74-th  step is running
# 完成第75个step的训练, each_rmse=[0.79142647], 耗时3.2382秒
# The 75-th  step is running
# 完成第76个step的训练, each_rmse=[0.79138008], 耗时3.2862秒
# The 76-th  step is running
# 完成第77个step的训练, each_rmse=[0.79133688], 耗时3.9752秒
# The 77-th  step is running
# 完成第78个step的训练, each_rmse=[0.79129672], 耗时3.1142秒
# The 78-th  step is running
# 完成第79个step的训练, each_rmse=[0.79125938], 耗时3.1002秒
# The 79-th  step is running
# 完成第80个step的训练, each_rmse=[0.79122466], 耗时3.0542秒
# The 80-th  step is running
# 完成第81个step的训练, each_rmse=[0.79119237], 耗时3.0332秒
# The 81-th  step is running
# 完成第82个step的训练, each_rmse=[0.79116235], 耗时3.0732秒
# The 82-th  step is running
# 完成第83个step的训练, each_rmse=[0.79113442], 耗时3.0302秒
# The 83-th  step is running
# 完成第84个step的训练, each_rmse=[0.79110847], 耗时3.1452秒
# The 84-th  step is running
# 完成第85个step的训练, each_rmse=[0.79108431], 耗时3.0072秒
# The 85-th  step is running
# 完成第86个step的训练, each_rmse=[0.79106186], 耗时3.0862秒
# The 86-th  step is running
# 完成第87个step的训练, each_rmse=[0.791041], 耗时3.0242秒
# The 87-th  step is running
# 完成第88个step的训练, each_rmse=[0.79102158], 耗时3.0912秒
# The 88-th  step is running
# 完成第89个step的训练, each_rmse=[0.79100351], 耗时3.0502秒
# The 89-th  step is running
# 完成第90个step的训练, each_rmse=[0.7909867], 耗时3.0502秒
# The 90-th  step is running
# 完成第91个step的训练, each_rmse=[0.79097108], 耗时3.3542秒
# The 91-th  step is running
# 完成第92个step的训练, each_rmse=[0.79095657], 耗时3.3672秒
# The 92-th  step is running
# 完成第93个step的训练, each_rmse=[0.79094306], 耗时3.0222秒
# The 93-th  step is running
# 完成第94个step的训练, each_rmse=[0.79093048], 耗时3.1092秒
# The 94-th  step is running
# 完成第95个step的训练, each_rmse=[0.79091881], 耗时3.0392秒
# The 95-th  step is running
# 完成第96个step的训练, each_rmse=[0.79090794], 耗时3.0612秒
# The 96-th  step is running
# 完成第97个step的训练, each_rmse=[0.79089784], 耗时3.0762秒
# The 97-th  step is running
# 完成第98个step的训练, each_rmse=[0.79088844], 耗时3.3182秒
# The 98-th  step is running
# 完成第99个step的训练, each_rmse=[0.79087971], 耗时3.0722秒
# The 99-th  step is running
# 完成第100个step的训练, each_rmse=[0.79087158], 耗时3.0412秒
# 结束了100个step的训练，总耗时311.6948秒

# %%
# 4.1.4、BiasSVD模型参数保存
# 模型参数保存为json， 键（模型参数）和值（模型参数值）
def BiasSVD_parameter_toJson(filepath):
    BiasSVD_parameter_dict = dict()
    BiasSVD_parameter_dict['average'] = average
    BiasSVD_parameter_dict['k'] = k
    
    # numpy.ndarray.map() 将列表转换为矩阵
    # numpy.ndarray.tolist() 将矩阵转换为列表
    BiasSVD_parameter_dict['bi'] = bi.tolist()
    BiasSVD_parameter_dict['bu'] = bu.tolist()
    
    BiasSVD_parameter_dict['qi'] = qi.tolist()
    BiasSVD_parameter_dict['pu'] = pu.tolist()

    # json.loads即可将JSON字符串转换成Python形式
    # json.dumps则将Python对象转换成JSON格式
    BiasSVD_parameter_toJsonTxt = json.dumps(BiasSVD_parameter_dict)
    with open(filepath, 'w') as file:
        file.write(BiasSVD_parameter_toJsonTxt)

# %%
# 4.1.5、BiasSVD模型参数加载
def BiasSVD_parameter_load_fromJson(filepath):
    with open(filepath, 'r') as file:
        BiasSVD_parameter_dict = json.load(file)

        average = BiasSVD_parameter_dict['average']
        K = BiasSVD_parameter_dict['k']

        # numpy.asarray 将数据转化为 ndarray 格式
        bi = np.asarray(BiasSVD_parameter_dict['bi'])
        bu = np.asarray(BiasSVD_parameter_dict['bu'])
    
        qi = np.asarray(BiasSVD_parameter_dict['qi'])
        pu = np.asarray(BiasSVD_parameter_dict['pu'])

# %%
# 4.1.4、BiasSVD模型参数保存
BiasSVD_parameter_toJson(data_path + 'BiasSVD_modelParameter.json')
# 4.1.5、BiasSVD模型参数加载
BiasSVD_parameter_load_fromJson(data_path + 'BiasSVD_modelParameter.json')

# %%
# 4.1.6、BiasSVD模型评测指标
# 数据集的总的样本空间数 T
# 真实的用户对物品的评分 rui
# 预测的用户对物品的评分 r`ui
# 真实评分与预测评分的差值 rss = rui - r`ui

# 对 rss 进行绝对值得到 rss_absolute
# 对 rss_absolute 进行求和得到 rss_absolute_sum
# MAE = rss_absolute_sum / T

# 对 rss 进行平方得到 rss_square
# 对 rss_square 进行求和得到 rss_square_sum
# RMSE = rss_square_sum / T
# MSE = rss_square / T

def calculate_MAE(dataset):
    # 真实评分与预测评分的差值的绝对值之和
    mae_sum = 0.0
    T = dataset.shape[0]
    total_num = np.random.permutation(T)
    for index in range(T):
        # 每次计算一个样本,即一条记录
        row = total_num[index]
        rating = dataset.iloc[row]['rating']
        
        # 预测残差
        eui = rating - BiasSVD_prediction(user_id, item_id)
        # residual sum of squares 残差平方和 
        mae_sum += abs(eui)
            
    # Root Mean Square Error RMSE
    MAE = mae_sum / total_records
    return MAE
    

def calculate_RMSE(dataset):
    # 真实评分与预测评分的差值的平方和
    rmse_sum = 0.0    
    T = dataset.shape[0]
    total_num = np.random.permutation(T)
    for index in range(T):
        # 每次计算一个样本,即一条记录
        row = total_num[index]
        rating = dataset.iloc[row]['rating']
        
        # 预测残差
        eui = rating - BiasSVD_prediction(user_id, item_id)
        # residual sum of squares 残差平方和 
        rmse_sum += eui**2
            
    # Root Mean Square Error RMSE
    RMSE = np.sqrt(rmse_sum / total_records)
    return RMSE

# %%
# 训练集评测指标：RMSE、MAE
print("the MAE of the RS of the train set :", calculate_MAE(train))
print("the RMSE of the RS of the train set :", calculate_RMSE(train))
# Out:
# the MAE of the RS of the train set : [0.87059867]
# the RMSE of the RS of the train set : [1.07564253]

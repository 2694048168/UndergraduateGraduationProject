# %%
# 模块和包都是在逐步的探索中所需要的，全部汇总到这里，
#    并不是一开始就知道了 ^_^ ^_^ ^_^ 
# 不熟悉的模块和包，强烈建议查看官方文档说明以及例子
# 1、导入模块和包
import pandas as pd    # 加载并处理csv文件
import datetime        # 利用datetime处理时间戳
# cPickle 数据以二进制进行高效的储存到文件
import _pickle as cPickle 
# defaultdict 设置稀疏矩阵的 NULL 位置的默认值
from collections import defaultdict 
# 利用scipy sparse 构建稀疏矩阵
import scipy.sparse as ss     
import scipy.io as sio    # 利用scipy储存评分矩阵
# 利用numpy创建指定长度或形状的矩阵以及矩阵运算
import numpy as np 
# numpy.random中的randn函数生成正态分布的随机数据
from numpy.random import random    
import time    # 计算训练时迭代的时间
import json    # 将模型参数保存和加载 json文件
import scipy    # 将储存加载的稀疏评分矩阵转换为numpy矩阵

# %%
# 4.2.1、LMF模型
# ############################################
#
# 核心算法实现
#
# @输入参数
#     R —— M*N 评分矩阵
#     k —— 隐向量的维度
#     theta —— 迭代次数
#     alpha —— 步长（学习率）
#     lamda —— 正则化系数
#
# @输出参数
#     分解之后的 P，Q
#     P：初始化用户特征矩阵 M*K
#     Q：初始化物品特征矩阵 N*K
#
# ############################################
# 设定模型参数\
# 18 个电影类型 1*18=18、2*18=36、3*18=54
K = 16
# 迭代次数：20、40、60、80、100
theta = 80
alpha = 0.04
lamda = 0.15
# 核心算法
def LFM_grad_desc( R, K, theta, alpha, lamda ):
    # 基本维度参数定义
    M = R.shape[0]
    N = R.shape[1]
    
    # P,Q初始值，随机生成
    P = np.random.rand(M, K)
    Q = np.random.rand(N, K)
    Q = Q.T
    
    # 第一次迭代时间开始
    time_start = time.time()
    print("开始进行{}个step的训练".format(theta))
    each_time_start = time_start
        
    # 开始迭代
    for step in range(theta):
        print('The {}-th  step is running'.format(step))
        # 对所有的用户u、物品i做遍历，
        # 对应的特征向量Pu、Qi梯度下降
        for u in range(M):
            for i in range(N):
                # 对于每一个大于0的评分，
                # 求出预测评分误差
                if R[u, i] > 0:
                    eui = np.dot( P[u,:], Q[:,i] ) - R[u, i]
                    
                    # 按照梯度下降算法更新当前的Pu、Qi
                    for k in range(K):
                        P[u][k] = P[u][k] - alpha * ( eui * Q[k][i] + lamda * P[u][k] )
                        Q[k][i] = Q[k][i] - alpha * ( eui * P[u][k] + lamda * Q[k][i] )
        
        # u、i遍历完成，所有特征向量更新完成，
        # 可以得到P、Q，可以计算预测评分矩阵
        predR = np.dot( P, Q )
        
        # 计算当前损失函数
        cost = 0
        for u in range(M):
            for i in range(N):
                if R[u, i] > 0:
                    cost += ( np.dot( P[u,:], Q[:,i] ) - R[u, i] ) ** 2
                    # 加上正则化项
                    for k in range(K):
                        cost += lamda * ( P[u][k] ** 2 + Q[k][i] ** 2 )
                        each_cost = np.sqrt(cost / K)
        # 每次迭代时间结束
        each_time_tick = time.time()
        # 每次迭代消耗的时间
        each_cost_time = each_time_tick - each_time_start
        # 更新计算每次迭代的时间
        each_time_start = each_time_tick
        print("完成第{}个step的训练, each_cost={}, 耗时{:.4f}秒".format( step + 1, cost, each_cost_time))
        
        if cost < 0.0001:
            break
    # 计算训练数据集消耗的总时间
    time_end = time.time()
    total_cost_time = time_end - time_start
    print("结束了{}个step的训练，总耗时{:.4f}秒".format(theta, total_cost_time))    
    return P, Q.T, cost

# %%
# 加载评分矩阵
data_path = "./../dataset/BX-CSV-Dump/"
user_item_score = sio.mmread(data_path + "user_item_score")
# todense() 转换为矩阵 numpy 
R = scipy.sparse.csc_matrix.todense(user_item_score)
type(R)
# Out:
# numpy.matrix

# %%
# 开始训练 LFM 模型
P, Q, ess = LFM_grad_desc( R, K, theta, alpha, lamda )
# Out:
# 开始进行80个step的训练
# The 0-th  step is running
# 完成第1个step的训练, each_cost=5071.82407674086, 耗时25.4025秒
# The 1-th  step is running
# 完成第2个step的训练, each_cost=2428.30570024566, 耗时24.6024秒
# The 2-th  step is running
# 完成第3个step的训练, each_cost=1936.9555259413457, 耗时24.0664秒
# The 3-th  step is running
# 完成第4个step的训练, each_cost=1859.2634231259572, 耗时22.3633秒
# The 4-th  step is running
# 完成第5个step的训练, each_cost=1841.632759960262, 耗时23.0523秒
# The 5-th  step is running
# 完成第6个step的训练, each_cost=1833.8909418587646, 耗时21.9993秒
# The 6-th  step is running
# 完成第7个step的训练, each_cost=1828.4322400637898, 耗时22.5573秒
# The 7-th  step is running
# 完成第8个step的训练, each_cost=1823.7449300678002, 耗时22.1033秒
# The 8-th  step is running
# 完成第9个step的训练, each_cost=1819.426104784929, 耗时22.1153秒
# The 9-th  step is running
# 完成第10个step的训练, each_cost=1815.3373518755488, 耗时22.1123秒
# The 10-th  step is running
# 完成第11个step的训练, each_cost=1811.42079909907, 耗时22.3393秒
# The 11-th  step is running
# 完成第12个step的训练, each_cost=1807.6478852429195, 耗时23.2553秒
# The 12-th  step is running
# 完成第13个step的训练, each_cost=1804.0021232183958, 耗时23.8384秒
# The 13-th  step is running
# 完成第14个step的训练, each_cost=1800.472566451827, 耗时26.4845秒
# The 14-th  step is running
# 完成第15个step的训练, each_cost=1797.0511120561985, 耗时26.8145秒
# The 15-th  step is running
# 完成第16个step的训练, each_cost=1793.7312902991441, 耗时26.7485秒
# The 16-th  step is running
# 完成第17个step的训练, each_cost=1790.507669903031, 耗时24.6564秒
# The 17-th  step is running
# 完成第18个step的训练, each_cost=1787.375538527922, 耗时24.6694秒
# The 18-th  step is running
# 完成第19个step的训练, each_cost=1784.3307164261273, 耗时25.5765秒
# The 19-th  step is running
# 完成第20个step的训练, each_cost=1781.3694394740655, 耗时26.0335秒
# The 20-th  step is running
# 完成第21个step的训练, each_cost=1778.4882807358322, 耗时26.2805秒
# The 21-th  step is running
# 完成第22个step的训练, each_cost=1775.6840946928394, 耗时24.8544秒
# The 22-th  step is running
# 完成第23个step的训练, each_cost=1772.9539755620794, 耗时22.5073秒
# The 23-th  step is running
# 完成第24个step的训练, each_cost=1770.2952248621707, 耗时23.2023秒
# The 24-th  step is running
# 完成第25个step的训练, each_cost=1767.705325376973, 耗时24.8844秒
# The 25-th  step is running
# 完成第26个step的训练, each_cost=1765.1819197642842, 耗时29.2947秒
# The 26-th  step is running
# 完成第27个step的训练, each_cost=1762.7227926801759, 耗时28.2516秒
# The 27-th  step is running
# 完成第28个step的训练, each_cost=1760.325855656371, 耗时27.4276秒
# The 28-th  step is running
# 完成第29个step的训练, each_cost=1757.9891341899495, 耗时25.5805秒
# The 29-th  step is running
# 完成第30个step的训练, each_cost=1755.7107566458023, 耗时26.7335秒
# The 30-th  step is running
# 完成第31个step的训练, each_cost=1753.4889446645475, 耗时23.0913秒
# The 31-th  step is running
# 完成第32个step的训练, each_cost=1751.3220048331013, 耗时23.0243秒
# The 32-th  step is running
# 完成第33个step的训练, each_cost=1749.2083214212394, 耗时27.0925秒
# The 33-th  step is running
# 完成第34个step的训练, each_cost=1747.146350022668, 耗时29.3137秒
# The 34-th  step is running
# 完成第35个step的训练, each_cost=1745.1346119665372, 耗时24.4944秒
# The 35-th  step is running
# 完成第36个step的训练, each_cost=1743.1716893874054, 耗时23.9544秒
# The 36-th  step is running
# 完成第37个step的训练, each_cost=1741.2562208593665, 耗时25.8705秒
# The 37-th  step is running
# 完成第38个step的训练, each_cost=1739.3868975153346, 耗时28.4526秒
# The 38-th  step is running
# 完成第39个step的训练, each_cost=1737.5624595843494, 耗时23.2343秒
# The 39-th  step is running
# 完成第40个step的训练, each_cost=1735.781693290288, 耗时23.0903秒
# The 40-th  step is running
# 完成第41个step的训练, each_cost=1734.0434280639088, 耗时24.0634秒
# The 41-th  step is running
# 完成第42个step的训练, each_cost=1732.346534027593, 耗时25.5435秒
# The 42-th  step is running
# 完成第43个step的训练, each_cost=1730.6899197175526, 耗时27.1676秒
# The 43-th  step is running
# 完成第44个step的训练, each_cost=1729.072530014238, 耗时22.4953秒
# The 44-th  step is running
# 完成第45个step的训练, each_cost=1727.4933442552326, 耗时22.6463秒
# The 45-th  step is running
# 完成第46个step的训练, each_cost=1725.9513745088173, 耗时26.5535秒
# The 46-th  step is running
# 完成第47个step的训练, each_cost=1724.4456639896039, 耗时25.2994秒
# The 47-th  step is running
# 完成第48个step的训练, each_cost=1722.9752855997563, 耗时24.1554秒
# The 48-th  step is running
# 完成第49个step的训练, each_cost=1721.5393405820923, 耗时24.0394秒
# The 49-th  step is running
# 完成第50个step的训练, each_cost=1720.136957272593, 耗时24.3054秒
# The 50-th  step is running
# 完成第51个step的训练, each_cost=1718.7672899421839, 耗时27.2186秒
# The 51-th  step is running
# 完成第52个step的训练, each_cost=1717.4295177180352, 耗时26.5795秒
# The 52-th  step is running
# 完成第53个step的训练, each_cost=1716.1228435769565, 耗时26.7045秒
# The 53-th  step is running
# 完成第54个step的训练, each_cost=1714.8464934034112, 耗时25.0814秒
# The 54-th  step is running
# 完成第55个step的训练, each_cost=1713.5997151061765, 耗时28.4836秒
# The 55-th  step is running
# 完成第56个step的训练, each_cost=1712.3817777880959, 耗时23.4743秒
# The 56-th  step is running
# 完成第57个step的训练, each_cost=1711.1919709643082, 耗时30.7798秒
# The 57-th  step is running
# 完成第58个step的训练, each_cost=1710.029603824595, 耗时26.3415秒
# The 58-th  step is running
# 完成第59个step的训练, each_cost=1708.8940045360346, 耗时24.9584秒
# The 59-th  step is running
# 完成第60个step的训练, each_cost=1707.7845195827856, 耗时26.0255秒
# The 60-th  step is running
# 完成第61个step的训练, each_cost=1706.7005131398457, 耗时31.9358秒
# The 61-th  step is running
# 完成第62个step的训练, each_cost=1705.641366478309, 耗时28.2416秒
# The 62-th  step is running
# 完成第63个step的训练, each_cost=1704.6064773995076, 耗时25.8965秒
# The 63-th  step is running
# 完成第64个step的训练, each_cost=1703.5952596961667, 耗时24.2944秒
# The 64-th  step is running
# 完成第65个step的训练, each_cost=1702.6071426384617, 耗时28.5926秒
# The 65-th  step is running
# 完成第66个step的训练, each_cost=1701.6415704831961, 耗时29.0167秒
# The 66-th  step is running
# 完成第67个step的训练, each_cost=1700.6980020047943, 耗时24.8794秒
# The 67-th  step is running
# 完成第68个step的训练, each_cost=1699.7759100463109, 耗时27.1106秒
# The 68-th  step is running
# 完成第69个step的训练, each_cost=1698.8747810895409, 耗时31.5268秒
# The 69-th  step is running
# 完成第70个step的训练, each_cost=1697.994114842726, 耗时26.3145秒
# The 70-th  step is running
# 完成第71个step的训练, each_cost=1697.133423844957, 耗时27.4256秒
# The 71-th  step is running
# 完成第72个step的训练, each_cost=1696.2922330862823, 耗时25.7555秒
# The 72-th  step is running
# 完成第73个step的训练, each_cost=1695.4700796424856, 耗时24.5904秒
# The 73-th  step is running
# 完成第74个step的训练, each_cost=1694.6665123239652, 耗时25.0614秒
# The 74-th  step is running
# 完成第75个step的训练, each_cost=1693.881091337552, 耗时22.8063秒
# The 75-th  step is running
# 完成第76个step的训练, each_cost=1693.1133879609245, 耗时26.4065秒
# The 76-th  step is running
# 完成第77个step的训练, each_cost=1692.3629842288046, 耗时24.9914秒
# The 77-th  step is running
# 完成第78个step的训练, each_cost=1691.6294726303913, 耗时22.2423秒
# The 78-th  step is running
# 完成第79个step的训练, each_cost=1690.9124558172875, 耗时21.9493秒
# The 79-th  step is running
# 完成第80个step的训练, each_cost=1690.211546321657, 耗时21.9383秒
# 结束了80个step的训练，总耗时2024.3188秒

# %%
# 通过训练的 P和 Q 计算出预测评分矩阵
pred_R = np.dot( P, Q.T )
# 将预测评分矩阵保存
sio.mmwrite(data_path + "pred_R", pred_R)

# %%
# 查看原始评分矩阵
print(R)
# 查看预测评分矩阵
print(pred_R)
# Out:
# [[ 0.  0.  0. ...  0.  0.  0.]
#  [ 0. 10.  0. ...  0.  0.  0.]
#  [ 0.  0.  6. ...  0.  0.  0.]
#  ...
#  [ 0.  0.  0. ...  4.  0.  0.]
#  [ 0.  0.  0. ...  0.  5.  0.]
#  [ 0.  0.  0. ...  0.  0.  0.]]
# [[2.9543619  4.12678778 2.96176654 ... 2.57494027 2.8081596  3.12045711]
#  [4.36364121 9.85162004 6.48141293 ... 5.76056107 6.30100043 5.08428771]
#  [3.30191753 6.16128313 5.85316684 ... 3.95818428 4.15632789 4.16597372]
#  ...
#  [3.32815127 6.52026194 4.50157933 ... 3.86164959 4.39651496 3.8632879 ]
#  [3.22373506 6.44220704 4.58782175 ... 3.67828396 4.85568411 3.8349583 ]
#  [3.71136521 4.54247141 3.65722122 ... 2.94600587 3.35376052 3.07940526]]

# %%
# 查看训练后的 P 和 Q 矩阵
print(P)
print("====================================================")
print(Q)
# Out:
# [[0.00468092 0.40087031 0.28547441 ... 0.73797073 0.55272424 0.53061885]
#  [0.75937665 0.48595437 0.30585587 ... 0.85160014 0.64951362 0.62342984]
#  [0.84318547 0.65630566 0.27864805 ... 0.33177051 0.97956943 0.4131765 ]
#  ...
#  [0.47293716 0.62860248 0.46227091 ... 0.53530048 0.43329437 0.4442142 ]
#  [0.83465556 0.5008916  0.24820184 ... 0.53286364 0.5616119  0.57069278]
#  [0.39045181 0.04260213 0.48856657 ... 0.06984424 0.74276618 0.3699813 ]]
# ====================================================
# [[0.08080875 0.08849171 0.87807062 ... 0.27572461 0.39584158 0.75256576]
#  [0.60105077 0.59872701 0.37296041 ... 0.91352148 0.73517096 0.75862097]
#  [0.99095435 0.5244761  0.28116595 ... 0.30451613 0.8609495  0.35814884]
#  ...
#  [0.58173809 0.27754387 0.26614914 ... 0.69979786 0.52855633 0.29516541]
#  [0.72274701 0.70404608 0.44724442 ... 0.75020163 0.58749634 0.32758831]
#  [0.32082338 0.80140605 0.70629455 ... 0.81623924 0.88339137 0.9031128 ]]

# %%
# LFM模型评测指标
# RMSE 和 MAE
def calc_evaluation(R, pred_R):
    mae_sum = 0.0
    rmse_sum = 0.0
    # 基本维度参数定义
    M = R.shape[0]
    N = R.shape[1]
    T = 0
    
    for user in range(M):
        for item in range(N):
            if R[user, item] > 0:
                T += 1
                ess = R[user, item] - pred_R[user, item]
                mae_sum += abs(ess)
                rmse_sum += ess**2
    
    # 计算总的 MAE 指标
    MAE = mae_sum / T
    # Root Mean Square Error RMSE
    RMSE = np.sqrt(rmse_sum / T)
    return MAE, RMSE

# %%
MAE, RMSE = calc_evaluation(R, pred_R)
print("the MAE of LFM:", MAE)
print("the RMSE OF LFM:", RMSE)
# Out:
# the MAE of LFM: 0.14668918203365244
# the RMSE OF LFM: 0.1472427659730991

# %%
# 模块和包都是在逐步的探索中所需要的，全部汇总到这里，
#    并不是一开始就知道了 ^_^ ^_^ ^_^ 
# 不熟悉的模块和包，强烈建议查看官方文档说明以及例子
# 1、导入模块和包
import pandas as pd    # 加载并处理csv文件
import datetime        # 利用datetime处理时间戳
# cPickle 数据以二进制进行高效的储存到文件
import _pickle as cPickle 
# defaultdict 设置稀疏矩阵的 NULL 位置的默认值
from collections import defaultdict 
# 利用scipy sparse 构建稀疏矩阵
import scipy.sparse as ss     
import scipy.io as sio    # 利用scipy储存评分矩阵
# 利用numpy创建指定长度或形状的矩阵以及矩阵运算
import numpy as np 
# numpy.random中的randn函数生成正态分布的随机数据
from numpy.random import random    
import time    # 计算训练时迭代的时间
import json    # 将模型参数保存和加载 json文件
import scipy    # 将储存加载的稀疏评分矩阵转换为numpy矩阵

# %%
# 4.2.1、LMF模型
# ############################################
#
# 核心算法实现
#
# @输入参数
#     R —— M*N 评分矩阵
#     k —— 隐向量的维度
#     theta —— 迭代次数
#     alpha —— 步长（学习率）
#     lamda —— 正则化系数
#
# @输出参数
#     分解之后的 P，Q
#     P：初始化用户特征矩阵 M*K
#     Q：初始化物品特征矩阵 N*K
#
# ############################################
# 设定模型参数\
# 18 个电影类型 1*18=18、2*18=36、3*18=54
K = 16
# 迭代次数：20、40、60、80、100
theta = 80
alpha = 0.04
lamda = 0.15
# 核心算法
def LFM_grad_desc( R, K, theta, alpha, lamda ):
    # 基本维度参数定义
    M = R.shape[0]
    N = R.shape[1]
    
    # P,Q初始值，随机生成
    P = np.random.rand(M, K)
    Q = np.random.rand(N, K)
    Q = Q.T
    
    # 第一次迭代时间开始
    time_start = time.time()
    print("开始进行{}个step的训练".format(theta))
    each_time_start = time_start
        
    # 开始迭代
    for step in range(theta):
        print('The {}-th  step is running'.format(step))
        # 对所有的用户u、物品i做遍历，
        # 对应的特征向量Pu、Qi梯度下降
        for u in range(M):
            for i in range(N):
                # 对于每一个大于0的评分，
                # 求出预测评分误差
                if R[u, i] > 0:
                    eui = np.dot( P[u,:], Q[:,i] ) - R[u, i]
                    
                    # 按照梯度下降算法更新当前的Pu、Qi
                    for k in range(K):
                        P[u][k] = P[u][k] - alpha * ( eui * Q[k][i] + lamda * P[u][k] )
                        Q[k][i] = Q[k][i] - alpha * ( eui * P[u][k] + lamda * Q[k][i] )
        
        # u、i遍历完成，所有特征向量更新完成，
        # 可以得到P、Q，可以计算预测评分矩阵
        predR = np.dot( P, Q )
        
        # 计算当前损失函数
        cost = 0
        for u in range(M):
            for i in range(N):
                if R[u, i] > 0:
                    cost += ( np.dot( P[u,:], Q[:,i] ) - R[u, i] ) ** 2
                    # 加上正则化项
                    for k in range(K):
                        cost += lamda * ( P[u][k] ** 2 + Q[k][i] ** 2 )
                        each_cost = np.sqrt(cost / K)
        # 每次迭代时间结束
        each_time_tick = time.time()
        # 每次迭代消耗的时间
        each_cost_time = each_time_tick - each_time_start
        # 更新计算每次迭代的时间
        each_time_start = each_time_tick
        print("完成第{}个step的训练, each_cost={}, 耗时{:.4f}秒".format( step + 1, cost, each_cost_time))
        
        if cost < 0.0001:
            break
    # 计算训练数据集消耗的总时间
    time_end = time.time()
    total_cost_time = time_end - time_start
    print("结束了{}个step的训练，总耗时{:.4f}秒".format(theta, total_cost_time))    
    return P, Q.T, cost

# %%
# 加载评分矩阵
data_path = "./../dataset/BX-CSV-Dump/"
user_item_score = sio.mmread(data_path + "user_item_score")
# todense() 转换为矩阵 numpy 
R = scipy.sparse.csc_matrix.todense(user_item_score)
type(R)
# Out:
# numpy.matrix

# %%
# 开始训练 LFM 模型
P, Q, ess = LFM_grad_desc( R, K, theta, alpha, lamda )
# Out:
# 开始进行80个step的训练
# The 0-th  step is running
# 完成第1个step的训练, each_cost=1556.3372448524672, 耗时22.2953秒
# The 1-th  step is running
# 完成第2个step的训练, each_cost=1286.4829695229348, 耗时21.5772秒
# The 2-th  step is running
# 完成第3个step的训练, each_cost=1184.8205522979802, 耗时21.5242秒
# The 3-th  step is running
# 完成第4个step的训练, each_cost=1140.789880940058, 耗时21.3562秒
# The 4-th  step is running
# 完成第5个step的训练, each_cost=1118.550601145831, 耗时21.3252秒
# The 5-th  step is running
# 完成第6个step的训练, each_cost=1105.1582712027584, 耗时21.3112秒
# The 6-th  step is running
# 完成第7个step的训练, each_cost=1095.6269354752053, 耗时21.2362秒
# The 7-th  step is running
# 完成第8个step的训练, each_cost=1087.9239681893448, 耗时21.2822秒
# The 8-th  step is running
# 完成第9个step的训练, each_cost=1081.171646982558, 耗时21.1592秒
# The 9-th  step is running
# 完成第10个step的训练, each_cost=1074.968153090898, 耗时21.3102秒
# The 10-th  step is running
# 完成第11个step的训练, each_cost=1069.118514440358, 耗时21.3852秒
# The 11-th  step is running
# 完成第12个step的训练, each_cost=1063.5224668060985, 耗时21.3322秒
# The 12-th  step is running
# 完成第13个step的训练, each_cost=1058.1252896802496, 耗时21.4292秒
# The 13-th  step is running
# 完成第14个step的训练, each_cost=1052.8951899188062, 耗时21.2292秒
# The 14-th  step is running
# 完成第15个step的训练, each_cost=1047.8124286217776, 耗时21.2602秒
# The 15-th  step is running
# 完成第16个step的训练, each_cost=1042.863880137591, 耗时21.4582秒
# The 16-th  step is running
# 完成第17个step的训练, each_cost=1038.0402072578274, 耗时21.3322秒
# The 17-th  step is running
# 完成第18个step的训练, each_cost=1033.334342692984, 耗时21.3512秒
# The 18-th  step is running
# 完成第19个step的训练, each_cost=1028.740644409076, 耗时21.4792秒
# The 19-th  step is running
# 完成第20个step的训练, each_cost=1024.2544092601806, 耗时21.2952秒
# The 20-th  step is running
# 完成第21个step的训练, each_cost=1019.8715827363967, 耗时21.3232秒
# The 21-th  step is running
# 完成第22个step的训练, each_cost=1015.5885791896516, 耗时21.0972秒
# The 22-th  step is running
# 完成第23个step的训练, each_cost=1011.4021661468665, 耗时21.2472秒
# The 23-th  step is running
# 完成第24个step的训练, each_cost=1007.3093869463397, 耗时21.2382秒
# The 24-th  step is running
# 完成第25个step的训练, each_cost=1003.3075070261971, 耗时21.5942秒
# The 25-th  step is running
# 完成第26个step的训练, each_cost=999.3939752938196, 耗时21.1892秒
# The 26-th  step is running
# 完成第27个step的训练, each_cost=995.5663954337917, 耗时21.4702秒
# The 27-th  step is running
# 完成第28个step的训练, each_cost=991.8225039826375, 耗时21.4172秒
# The 28-th  step is running
# 完成第29个step的训练, each_cost=988.1601531572632, 耗时21.5162秒
# The 29-th  step is running
# 完成第30个step的训练, each_cost=984.5772971220235, 耗时21.3902秒
# The 30-th  step is running
# 完成第31个step的训练, each_cost=981.0719808099652, 耗时21.4162秒
# The 31-th  step is running
# 完成第32个step的训练, each_cost=977.6423306862558, 耗时21.2342秒
# The 32-th  step is running
# 完成第33个step的训练, each_cost=974.2865470193151, 耗时21.1822秒
# The 33-th  step is running
# 完成第34个step的训练, each_cost=971.002897342978, 耗时21.3392秒
# The 34-th  step is running
# 完成第35个step的训练, each_cost=967.7897108738729, 耗时21.3882秒
# The 35-th  step is running
# 完成第36个step的训练, each_cost=964.6453737049717, 耗时21.3242秒
# The 36-th  step is running
# 完成第37个step的训练, each_cost=961.5683246364769, 耗时21.4902秒
# The 37-th  step is running
# 完成第38个step的训练, each_cost=958.5570515355824, 耗时21.3532秒
# The 38-th  step is running
# 完成第39个step的训练, each_cost=955.6100881381055, 耗时21.2872秒
# The 39-th  step is running
# 完成第40个step的训练, each_cost=952.7260112226267, 耗时21.3632秒
# The 40-th  step is running
# 完成第41个step的训练, each_cost=949.9034381001419, 耗时21.3422秒
# The 41-th  step is running
# 完成第42个step的训练, each_cost=947.1410243729689, 耗时21.2292秒
# The 42-th  step is running
# 完成第43个step的训练, each_cost=944.4374619244043, 耗时21.2942秒
# The 43-th  step is running
# 完成第44个step的训练, each_cost=941.7914771071472, 耗时21.3902秒
# The 44-th  step is running
# 完成第45个step的训练, each_cost=939.2018291037791, 耗时21.4142秒
# The 45-th  step is running
# 完成第46个step的训练, each_cost=936.6673084368821, 耗时21.3872秒
# The 46-th  step is running
# 完成第47个step的训练, each_cost=934.1867356095938, 耗时21.2542秒
# The 47-th  step is running
# 完成第48个step的训练, each_cost=931.7589598606604, 耗时21.5572秒
# The 48-th  step is running
# 完成第49个step的训练, each_cost=929.3828580201099, 耗时21.6072秒
# The 49-th  step is running
# 完成第50个step的训练, each_cost=927.0573334537235, 耗时21.3072秒
# The 50-th  step is running
# 完成第51个step的训练, each_cost=924.781315086312, 耗时21.2622秒
# The 51-th  step is running
# 完成第52个step的训练, each_cost=922.5537564949589, 耗时21.2982秒
# The 52-th  step is running
# 完成第53个step的训练, each_cost=920.3736350647266, 耗时21.2972秒
# The 53-th  step is running
# 完成第54个step的训练, each_cost=918.2399512002595, 耗时22.5933秒
# The 54-th  step is running
# 完成第55个step的训练, each_cost=916.1517275876531, 耗时21.2312秒
# The 55-th  step is running
# 完成第56个step的训练, each_cost=914.1080085014745, 耗时21.3442秒
# The 56-th  step is running
# 完成第57个step的训练, each_cost=912.107859152705, 耗时21.3862秒
# The 57-th  step is running
# 完成第58个step的训练, each_cost=910.1503650736959, 耗时21.3412秒
# The 58-th  step is running
# 完成第59个step的训练, each_cost=908.2346315368214, 耗时21.6622秒
# The 59-th  step is running
# 完成第60个step的训练, each_cost=906.3597830037359, 耗时21.2752秒
# The 60-th  step is running
# 完成第61个step的训练, each_cost=904.5249626027693, 耗时21.3262秒
# The 61-th  step is running
# 完成第62个step的训练, each_cost=902.7293316318792, 耗时21.2382秒
# The 62-th  step is running
# 完成第63个step的训练, each_cost=900.9720690853203, 耗时21.5492秒
# The 63-th  step is running
# 完成第64个step的训练, each_cost=899.2523712018747, 耗时21.2722秒
# The 64-th  step is running
# 完成第65个step的训练, each_cost=897.5694510332615, 耗时21.5162秒
# The 65-th  step is running
# 完成第66个step的训练, each_cost=895.9225380309529, 耗时21.2982秒
# The 66-th  step is running
# 完成第67个step的训练, each_cost=894.3108776501697, 耗时21.3172秒
# The 67-th  step is running
# 完成第68个step的训练, each_cost=892.7337309698812, 耗时21.3032秒
# The 68-th  step is running
# 完成第69个step的训练, each_cost=891.19037432748, 耗时21.7292秒
# The 69-th  step is running
# 完成第70个step的训练, each_cost=889.6800989673781, 耗时21.1832秒
# The 70-th  step is running
# 完成第71个step的训练, each_cost=888.2022107024229, 耗时21.4752秒
# The 71-th  step is running
# 完成第72个step的训练, each_cost=886.7560295873643, 耗时21.2622秒
# The 72-th  step is running
# 完成第73个step的训练, each_cost=885.340889603606, 耗时21.4252秒
# The 73-th  step is running
# 完成第74个step的训练, each_cost=883.9561383545084, 耗时21.2752秒
# The 74-th  step is running
# 完成第75个step的训练, each_cost=882.6011367706612, 耗时21.3962秒
# The 75-th  step is running
# 完成第76个step的训练, each_cost=881.2752588244537, 耗时21.5082秒
# The 76-th  step is running
# 完成第77个step的训练, each_cost=879.9778912534737, 耗时21.5772秒
# The 77-th  step is running
# 完成第78个step的训练, each_cost=878.708433292175, 耗时21.2002秒
# The 78-th  step is running
# 完成第79个step的训练, each_cost=877.4662964114415, 耗时21.2592秒
# The 79-th  step is running
# 完成第80个step的训练, each_cost=876.2509040654734, 耗时21.3652秒
# 结束了80个step的训练，总耗时1710.7438秒

# %%
# 通过训练的 P和 Q 计算出预测评分矩阵
pred_R = np.dot( P, Q.T )
# 将预测评分矩阵保存
sio.mmwrite(data_path + "pred_R", pred_R)

# %%
# 查看原始评分矩阵
print(R)
# 查看预测评分矩阵
print(pred_R)
# Out:
# [[ 0.  0.  0. ...  0.  0.  0.]
#  [ 0. 10.  0. ...  0.  0.  0.]
#  [ 0.  0.  6. ...  0.  0.  0.]
#  ...
#  [ 0.  0.  0. ...  4.  0.  0.]
#  [ 0.  0.  0. ...  0.  5.  0.]
#  [ 0.  0.  0. ...  0.  0.  0.]]
# [[3.96721748 3.42702335 2.91267433 ... 2.24869418 2.2796187  3.06555235]
#  [4.52907257 4.85635886 3.08850978 ... 2.96170881 2.82823102 4.12260219]
#  [4.06449997 3.01765911 2.86766152 ... 2.49347607 2.21585425 3.38163361]
#  ...
#  [2.66174109 2.26134594 1.92663625 ... 1.87469318 1.60711235 2.11666156]
#  [3.74082535 3.52250887 2.69288849 ... 2.41623118 2.36875035 3.55470725]
#  [4.48982368 4.33140652 3.29320487 ... 2.77492591 2.64757183 3.95179228]]

# %%
# 查看训练后的 P 和 Q 矩阵
print(P)
print("====================================================")
print(Q)
# Out:
# [[0.03110579 0.90092573 0.10061658 ... 0.60953477 0.03940641 0.21467996]
#  [0.44270401 0.87259874 0.86676969 ... 0.52550093 0.68544395 0.5310504 ]
#  [0.63467921 0.25632915 0.44791758 ... 0.28532077 0.33009696 0.09333528]
#  ...
#  [0.37542351 0.31288138 0.20981461 ... 0.25432703 0.13745457 0.2213469 ]
#  [0.08530476 0.47724678 0.57152931 ... 0.45820884 0.44714744 0.39290853]
#  [0.0241565  0.91600459 0.29446936 ... 0.79659843 0.88448111 0.62515252]]
# ====================================================
# [[0.80610512 0.93504496 0.11566151 ... 0.87151794 0.42681622 0.11185077]
#  [0.46218514 0.78289453 0.66194    ... 0.68970322 0.43536483 0.75562124]
#  [0.32614656 0.65274206 0.31470409 ... 0.09986914 0.57197932 0.07601742]
#  ...
#  [0.23361816 0.16750703 0.42494413 ... 0.64421337 0.19562474 0.40976416]
#  [0.20695398 0.2447751  0.45872985 ... 0.48627968 0.0929761  0.55330531]
#  [0.36344401 0.19872457 0.94017584 ... 0.09782842 0.90329149 0.07286373]]

# %%
# LFM模型评测指标
# RMSE 和 MAE
def calc_evaluation(R, pred_R):
    mae_sum = 0.0
    rmse_sum = 0.0
    # 基本维度参数定义
    M = R.shape[0]
    N = R.shape[1]
    T = 0
    
    for user in range(M):
        for item in range(N):
            if R[user, item] > 0:
                T += 1
                ess = R[user, item] - pred_R[user, item]
                mae_sum += abs(ess)
                rmse_sum += ess**2
    
    # 计算总的 MAE 指标
    MAE = mae_sum / T
    # Root Mean Square Error RMSE
    RMSE = np.sqrt(rmse_sum / T)
    return MAE, RMSE

# %%
MAE, RMSE = calc_evaluation(R, pred_R)
print("the MAE of LFM:", MAE)
print("the RMSE OF LFM:", RMSE)
# Out:
# the MAE of LFM: 3.930479728104465
# the RMSE OF LFM: 4.048104826394875
